# %%
data_panen ={
    'lokasil': {
    'nama_lokasi': 'Kebun A',
    'hasil_panen': {
    'padi': 1200,
    'jagung': 800,
    'kedelai': 500
    }
},
    'lokasi2': {
    'nama_lokasi': 'Kebun B',
    'hasil_panen': {
    'padi': 1500,
    'jagung': 900,
    'kedelai': 450
    }
},
    'lokasi3': {
    'nama_lokasi': 'Kebun C',
    'hasil_panen': {
    'padi': 1100,
    'jagung': 750,
    'kedelai': 600
    }
},
    'lokasi4': {
    'nama_lokasi': 'Kebun D',
    'hasil_panen': {
    'padi': 1300,
    'jagung': 850,
    'kedelai': 550
    }
},
    'lokasi5': {
    'nama_lokasi': 'Kebun E',
    'hasil_panen': {
    'padi': 1400,
    'jagung': 950,
    'kedelai': 480
    }
}
}


for lokasinum, namalok in data_panen.items():
    print(f"{lokasinum} : {namalok['nama_lokasi']}")
    for tanaman, isi in namalok['hasil_panen'].items():
        print(f"{tanaman} : {isi}")
# Out:
# lokasil : Kebun A
# padi : 1200
# jagung : 800
# kedelai : 500
# lokasi2 : Kebun B
# padi : 1500
# jagung : 900
# kedelai : 450
# lokasi3 : Kebun C
# padi : 1100
# jagung : 750
# kedelai : 600
# lokasi4 : Kebun D
# padi : 1300
# jagung : 850
# kedelai : 550
# lokasi5 : Kebun E
# padi : 1400
# jagung : 950
# kedelai : 480

# %%
print(f"Jumlah tanaman jagung untuk lokasi 2 adalah {data_panen['lokasi2']['hasil_panen']['jagung']}")
# Out:
# Jumlah tanaman jagung untuk lokasi 2 adalah 900

# %%
for a,b in data_panen.items():
    if b['hasil_panen']['padi'] > 1300 or b['hasil_panen']['jagung'] >800:
     print (f" {a}  dengan nama lokasi hasil panen adalah {b['hasil_panen']['padi']} jagung {b['hasil_panen']['jagung']} memerlukan perhatian khusus" )
    else:
       print (f" {a}  dengan nama lokasi hasil panen adalah {b['hasil_panen']['padi']} jagung {b['hasil_panen']['jagung']} dalam kondisi baik" )
print("perubahan")
print("njdvuhsvidvf")
# Out:
#  lokasil  dengan nama lokasi hasil panen adalah 1200 jagung 800 dalam kondisi baik
#  lokasi2  dengan nama lokasi hasil panen adalah 1500 jagung 900 memerlukan perhatian khusus
#  lokasi3  dengan nama lokasi hasil panen adalah 1100 jagung 750 dalam kondisi baik
#  lokasi4  dengan nama lokasi hasil panen adalah 1300 jagung 850 memerlukan perhatian khusus
#  lokasi5  dengan nama lokasi hasil panen adalah 1400 jagung 950 memerlukan perhatian khusus
